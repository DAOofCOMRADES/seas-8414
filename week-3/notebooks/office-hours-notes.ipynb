# %%
100 = population
70 = training
30 = testing

training accuracy = 80%
testing accuracy = 76%

# %%
1000 = population
700 = training
300 = testing

 training accuracy =  higher (karan + ferda + terr + sara + cody) => higher (mickey + andy + Gbenga) 
 testing accuracy = lower (karan + ferda + terr + sara + cody) => higher (mickey + andy + Gbenga) 


1. If there is variety in training and no change testing data, training accuracy and testing accuracy increases
2. If there is no variety in training data and no change in testing data, training accuracy and testing accuracy the by and large same
3. If there is variety in training and varitey in testing data, training accuracy will rise and testing accuracy decrease.

# %%
10000 = population
7000 = training
3000 = testing

training accuracy =  equal
testing accuracy = equal

# %%
# clue #1

1. Increase in variety = accuracy increases
2. Large data set without variety = no change in accuracy
3. Noisy data = accuracy decreases

1, 2, 3...9 => 100, 888, 9999

# %%
How to choose?

===
100 million is mall for a model used by 8 billion.
100 is large for a model used by 1000 people.
===

1. Small size: cross-validation (k-fold ... 1...100)
2. Medium size: 50%/50%; CV5 (A B C D) => A, B/T; C= V; D= Testing (round 1);C, D/T; B= V; A= Testing (round 2); A, D/T; B= V; C= Testing (round 3);
3. Large size:  70% (training) /10% (validation)/ 20% (testing)

======
=> Forward selection: 
  20% training & 80% testing => accuracy 40%
  30% training & 70% testing => accuracy 50%
  45% training & 55% testing => accuracy 70% 

  30% expert systems (decision support system) => explainable system
