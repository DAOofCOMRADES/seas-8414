# %% [markdown]
# # Import Modules

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Generate Data

# %%
#@title
m = 3

# %%
#@title
d = { "output": list(), "input": list()}
for i in range(100):
    d["output"].append(i * 4)
    d["input"].append(i)

# %%
#@title
dataset = pd.DataFrame(d)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
dataset[["input", "output"]]
# Out:
#     input  output
# 0       0       0
# 1       1       4
# 2       2       8
# 3       3      12
# 4       4      16
# ..    ...     ...
# 95     95     380
# 96     96     384
# 97     97     388
# 98     98     392
# 99     99     396
#
# [100 rows x 2 columns]

# %%
#@title
# dataset.head(5).style.hide_index()
dataset[dataset.input % 13 == 0].head(5).tail(3).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_57e26e32_40f6_11ec_9391_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="col_heading level0 col0" >output</th>        <th class="col_heading level0 col1" >input</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_57e26e32_40f6_11ec_9391_0242ac1c0002row0_col0" class="data row0 col0" >78</td>
#                         <td id="T_57e26e32_40f6_11ec_9391_0242ac1c0002row0_col1" class="data row0 col1" >26</td>
#             </tr>
#             <tr>
#                                 <td id="T_57e26e32_40f6_11ec_9391_0242ac1c0002row1_col0" class="data row1 col0" >117</td>
#                         <td id="T_57e26e32_40f6_11ec_9391_0242ac1c0002row1_col1" class="data row1 col1" >39</td>
#             </tr>
#             <tr>
#                                 <td id="T_57e26e32_40f6_11ec_9391_0242ac1c0002row2_col0" class="data row2 col0" >156</td>
#                         <td id="T_57e26e32_40f6_11ec_9391_0242ac1c0002row2_col1" class="data row2 col1" >52</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Run Machine Learning Algorithm

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
global regressor
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %% [markdown]
# # Test the Model

# %%
input_value = 500

# %%
#@title
def predict(n):
    global regressor
    return round(regressor.predict([[n]])[0])

# %%
print("For input", input_value, "prediction is", predict(input_value))
# Out:
# For input 500 prediction is 167
